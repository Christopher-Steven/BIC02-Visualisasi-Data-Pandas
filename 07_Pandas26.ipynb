# %% [markdown]
# ## Pertemuan 7 Pandas 26
# - ### Sumber : https://youtu.be/s8ErmUx_aLE?t=1
# - ### Membentuk data frame dari hasil spreadsheet

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.1.3

# %% [markdown]
# ### Data Frame

# %%
df = pd.read_clipboard()
df
# Out:
#       No                             Resiko  \
# 0    1.0               Terjadinya kebakaran
# 1    2.0                        Kabel putus
# 2    3.0             Router wifi bermasalah
# 3    4.0           Pemutusan Aliran Listrik
# 4    5.0                      Provider down
# 5    6.0                            malware
# 6    NaN  New risks and Uncontrollable risk
# 7    7.0                        Server down
# 8    8.0                     Hardware rusak
# 9    9.0                    Hardware hilang
# 10   NaN           ada hardware yang hilang
# 11  10.0            Hardware ketumpahan air
# 12  11.0         Internet Lab terkena DDOS,
# 13  12.0  Data dalam komputer terjadi korup
# 14  13.0                    Backdoor Attack
# 15  14.0                       Smurf Attack
# 16  15.0                      Firewall Mati
#
#                                                 Sebab  \
# 0                             short circuit (korslet)
# ...

# %% [markdown]
# - cara untuk mengcopy data kedalam data frame menggunakan `read_clipboard()` dan hanya tinggal melakukan **copy** pada excel ataupun sparesheet yang ingin kita masukan lalu run kembali kodenya.
# - perlu di perhatikan **data pertama yang di copy** akan merepresentasikan nama kolom.
